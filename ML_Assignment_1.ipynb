# %% [markdown]
# ## ***`LIFE EXPECTANCY DATASET  (CSV)`***

# %%
from google.colab import drive
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds = pd.read_csv("/content/drive/MyDrive/ML/Life Expectancy Data-1.csv") # ds = dataset

# %%
ds.head(9)
# Out:
#        Country  Year  ... Income composition of resources  Schooling
# 0  Afghanistan  2015  ...                           0.479       10.1
# 1  Afghanistan  2014  ...                           0.476       10.0
# 2  Afghanistan  2013  ...                           0.470        9.9
# 3  Afghanistan  2012  ...                           0.463        9.8
# 4  Afghanistan  2011  ...                           0.454        9.5
# 5  Afghanistan  2010  ...                           0.448        9.2
# 6  Afghanistan  2009  ...                           0.434        8.9
# 7  Afghanistan  2008  ...                           0.433        8.7
# 8  Afghanistan  2007  ...                           0.415        8.4
#
# [9 rows x 22 columns]

# %%
ds.tail(9)
# Out:
#        Country  Year  ... Income composition of resources  Schooling
# 2929  Zimbabwe  2008  ...                           0.421        9.7
# 2930  Zimbabwe  2007  ...                           0.414        9.6
# 2931  Zimbabwe  2006  ...                           0.408        9.5
# 2932  Zimbabwe  2005  ...                           0.406        9.3
# 2933  Zimbabwe  2004  ...                           0.407        9.2
# 2934  Zimbabwe  2003  ...                           0.418        9.5
# 2935  Zimbabwe  2002  ...                           0.427       10.0
# 2936  Zimbabwe  2001  ...                           0.427        9.8
# 2937  Zimbabwe  2000  ...                           0.434        9.8
#
# [9 rows x 22 columns]

# %%
ds.isnull().sum()  # to display the null no.of null values in the csv file
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Life expectancy                     10
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
ds.dropna(inplace=True) #to remove the null values from the csv file

# %%
ds.isnull().sum() # after removing the NULL values
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
ds.dtypes
# Out:
# Country                             object
# Year                                 int64
# Status                              object
# Life expectancy                    float64
# Adult Mortality                    float64
# infant deaths                        int64
# Alcohol                            float64
# percentage expenditure             float64
# Hepatitis B                        float64
# Measles                              int64
#  BMI                               float64
# under-five deaths                    int64
# Polio                              float64
# Total expenditure                  float64
# Diphtheria                         float64
#  HIV/AIDS                          float64
# GDP                                float64
# Population                         float64
#  thinness  1-19 years              float64
#  thinness 5-9 years                float64
# Income composition of resources    float64
# Schooling                          float64
# ...

# %%
Life_expectancy  = ds.iloc[:, 3] # this is our " Y "  value

# %%
x1 = ds.iloc[:, 1] # column -:- Year

# %%
plt.scatter(x1, Life_expectancy)
plt.title("Life_expectancy vs year")
plt.xlabel(' Year')
plt.ylabel('Life_expectancy')
plt.show()

# %%
x2 = ds.iloc[:, 4] ## Adult Mortality
x3 = ds.iloc[:, 5] ## Infant Mortality
x4 = ds.iloc[:, 6] ## Alcohol
x5 = ds.iloc[:, 7] ## Percentage Expenditure
x6 = ds.iloc[:, 8] ## Hepatitis - B
x7 = ds.iloc[:, 9]## Measles
x8 = ds.iloc[:, 10]##BMI
x9 = ds.iloc[:, 11]##Underfive deaths
x10 = ds.iloc[:, 12]## Polio
x11 = ds.iloc[:, 13]## Total expenditure
x12 = ds.iloc[:, 14]##Diptheria
x13 = ds.iloc[:, 15]## HIV/ AIDS
x14 = ds.iloc[:, 16]## GDP

x15 = ds.iloc[:, 17] ## Population
x16= ds.iloc[:, 18]## Thinness 1-19 years
x17 = ds.iloc[:, 19]##  Thinness 5 - 9 years
x18 = ds.iloc[:, 20]## Income composition of resources 
x19 = ds.iloc[:, 21]## Schoolings

# %%
ds.shape
# Out:
# (1649, 22)

# %%
plt.scatter(x2, Life_expectancy)
plt.title("Life_expectancy vs Adult_mortality")
plt.xlabel(' Adult_mortality')
plt.ylabel('Life_expectancy')
plt.show()



plt.scatter(x3, Life_expectancy)
plt.title("Life_expectancy vs Infant_Deaths")
plt.xlabel(' Infants deaths')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x3, Life_expectancy)
plt.title("Life_expectancy vs Infant_Deaths")
plt.xlabel(' Infants deaths')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x4, Life_expectancy)
plt.title("Life_expectancy vs Alcohol")
plt.xlabel(' Alcohol')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x5, Life_expectancy)
plt.title("Life_expectancy vs Pecentage_Expenditure")
plt.xlabel(' Percentage expenditure')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x6, Life_expectancy)
plt.title("Life_expectancy vs Hepatitis")
plt.xlabel(' Hepatitis')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x7, Life_expectancy)
plt.title("Life_expectancy vs measles")
plt.xlabel(' measles')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x8, Life_expectancy)
plt.title("Life_expectancy vs BMT")
plt.xlabel(' BMT')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x9, Life_expectancy)
plt.title("Life_expectancy vs Under five deaths")
plt.xlabel(' under five deaths')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x10, Life_expectancy)
plt.title("Life_expectancy vs polio")
plt.xlabel(' polio')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x11 , Life_expectancy)
plt.title("Life_expectancy vs Total expenditure")
plt.xlabel(' total expenditure')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x12, Life_expectancy)
plt.title("Life_expectancy vs Diptheria")
plt.xlabel(' Diptheria')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x13, Life_expectancy)
plt.title("Life_expectancy vs HIV/AIDS")
plt.xlabel(' HIV/AIDS')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x14, Life_expectancy)
plt.title("Life_expectancy vs GDP")
plt.xlabel(' GDP')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x15, Life_expectancy)
plt.title("Life_expectancy vs populationn")
plt.xlabel(' Population')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x16, Life_expectancy)
plt.title("Life_expectancy vs thinness 1 - 19 years")
plt.xlabel(' thinness 1- 19 years')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x17, Life_expectancy)
plt.title("Life_expectancy vs thinness 5 - 9 years")
plt.xlabel(' thinness 5 - 9 years')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x18, Life_expectancy)
plt.title("Life_expectancy vs Income composition")
plt.xlabel(' income composition')
plt.ylabel('Life_expectancy')
plt.show()

# %%
plt.scatter(x19, Life_expectancy)
plt.title("Life_expectancy vs schooling")
plt.xlabel(' schooing')
plt.ylabel('Life_expectancy')
plt.show()
